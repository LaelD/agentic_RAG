# %%
# %pip install python-dotenv langchain langchain.document_loaders langchain-openai langchain-pinecone langchain-community pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\user\appdata\roaming\python\python314\site-packages (1.2.1)
# Requirement already satisfied: langchain in c:\users\user\appdata\roaming\python\python314\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement langchain.document_loaders (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for langchain.document_loaders

# %%
from dotenv import load_dotenv
from langchain.document_loaders import TextLoader, PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore


# Load environment variables from .env file
load_dotenv()

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small", show_progress_bar=False, chunk_size=50, retry_min_seconds=10
)
vectorstore = PineconeVectorStore(
    index_name="rag-agriculture",
    embedding=embeddings,
)

# Load PDF files from docs folder
def load_pdf_files(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader,
    )
    return loader.load()

extract_text = load_pdf_files("docs")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from langchain.document_loaders import TextLoader, PyPDFLoader, DirectoryLoader
#       3 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       4 from langchain_core.documents import Document
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'
